# %%
import torch

# %%
b=torch.range(start=-1, end=1, step=0.05)
b
# Out:
# <ipython-input-21-6323a17e9dae>:1: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   b=torch.range(start=-1, end=1, step=0.05)
# tensor([-1.0000, -0.9500, -0.9000, -0.8500, -0.8000, -0.7500, -0.7000, -0.6500,
#         -0.6000, -0.5500, -0.5000, -0.4500, -0.4000, -0.3500, -0.3000, -0.2500,
#         -0.2000, -0.1500, -0.1000, -0.0500,  0.0000,  0.0500,  0.1000,  0.1500,
#          0.2000,  0.2500,  0.3000,  0.3500,  0.4000,  0.4500,  0.5000,  0.5500,
#          0.6000,  0.6500,  0.7000,  0.7500,  0.8000,  0.8500,  0.9000,  0.9500,
#          1.0000])

# %%
device_Binarize_sub_th(b)
# Out:
# tensor([-0.8889, -0.8824, -0.8750, -0.8667, -0.8571, -0.8462, -0.8333, -0.8182,
#         -0.8000, -0.7778, -0.7500, -0.7143, -0.6667, -0.6000, -0.5000, -0.3333,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.3333,  0.5000,  0.6000,  0.6667,  0.7143,  0.7500,  0.7778,
#          0.8000,  0.8182,  0.8333,  0.8462,  0.8571,  0.8667,  0.8750,  0.8824,
#          0.8889])
